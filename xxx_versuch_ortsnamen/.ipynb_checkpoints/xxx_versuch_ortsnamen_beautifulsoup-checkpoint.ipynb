# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
r = requests.get('https://search.ortsnamen.ch/de/?query=kanton:"ZH"')
#soup = BeautifulSoup(r.text, 'lxml')
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup

# %%
#soup = BeautifulSoup()

# %%
#soup.find('div', {'class':'resultpart result-body'}).find_all('div', {'class':'display-table-cell table-col-3'})

# %%
soup.find_all('div',{'id' : "search_list"})

# %%
#soup.find_all('table',{'id' : "data"})

# %%
#soup.find('record_detail')

# %% [markdown]
# 81931 einträge

# %%
r = requests.get('https://search.ortsnamen.ch/de/?query=kanton:"ZH"')
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html>
# <head>
# <script type="text/javascript">
# var query_string;
# var custom_center;
# var custom_resolution;
# var ajax_search_url = "/de/search_records";
#  query_string = 'kanton:&quot;ZH&quot;';
#
#
# function get_record_snippet_id(id, provider) {
#   return "/de/record_snippet/6789/12345".replace("12345", id).replace("6789", provider)
# }
#
# </script>
# <link href="/static/onch/img/favicon.ico" rel="shortcut icon"/>
# <link href="/static/onch/css/font-awesome-4.2.0/css/font-awesome.min.css?v=566e" rel="stylesheet" type="text/css"/>
# <link href="/static/lightGallery-1.6.12/dist/css/lightgallery.min.css?v=566e" rel="stylesheet" type="text/css"/>
# <link href="/static/onch/css/main.css?v=566e" rel="stylesheet" type="text/css"/>
# <link href="/static/onch/css/easydropdown.css?v=566e" rel="stylesheet" type="text/css"/>
# <link href="/static/onch/css/navbar_record_snippet.css?v=566e" rel="stylesheet" type="text/css"/>
# ...

# %%
trlist = soup.find_all("tr")[0:]
trlist
# Out:
# []

# %%
r = requests.get('https://search.ortsnamen.ch/de/?query=kanton:"ZH"')
alleeintraege = []

soup = BeautifulSoup(r.text, 'html.parser')
    
trlist = soup.find_all("tr")[0:]
    
for element in trlist:
    
    div_list = element.find_all('div')
    href = td_list[0].find('a')['href']
    Name = td_list[1].text
    Ortstyp = td_list[2].text
    Gemeinde = td_list[3].text
    Bezirk = td_list[4].text
    Kanton = td_list[5].text
    Hoehe = td_list[6].text
    Datenherkunft = td_list[7].text


    mini_dict = {"url": href,
        "Name": Name,
        "Ortstyp": Ortstyp,
        "Gemeinde": Gemeinde,
        "Bezirk":Bezirk,
        "Kanton": Kanton,
        "Hoehe": Hoehe,
        "Datenherkunft": Datenherkunft}
    
    alleeintraege.append(mini_dict)

# %%
alleeintraege
# Out:
# []

# %%
pd.DataFrame(alleeintraege)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
