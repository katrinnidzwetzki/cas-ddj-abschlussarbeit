# %% [markdown]
# # Daten herunterladen:
# https://drive.google.com/open?id=1kCYv7qOFqk_hldi7rKaBkZovVTyndVfP oder
#
# https://shop.swisstopo.admin.ch/de/products/landscape/names3D
#
# swissNAMES3D_LV95
#
# shp_LV95_LN02
#
# Benötigte Dateien:
#
# swissNAMES3D_PKT.dbf
#
# swissNAMES3D_PKT.prj
#
# swissNAMES3D_PKT.shp
#
# swissNAMES3D_PKT.shx

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString, Polygon
# %matplotlib inline
import re

# %%
# Daten einlesen
gdf = gpd.read_file('shp_LV95_LN02/swissNAMES3D_PKT.shx')

# %%
gdf
# Out:
#                                           UUID          OBJEKTART  \
# 0       {2FF7E3F1-6BAA-4981-A172-A459E01982E8}           Ausfahrt
# 1       {AA4D0B0F-CA43-4B91-BFC3-32B9F3E2FEDB}           Ausfahrt
# 2       {358C0BD3-3DF7-4A49-B446-F156A2D3D865}           Ausfahrt
# 3       {C4D61C3F-4A22-4474-9FD8-9532845AFFF4}           Ausfahrt
# 4       {082BA123-C0B5-47E3-9D86-8AC0DFD1025F}           Ausfahrt
# 5       {674B9162-0FCF-4972-B9A3-FDB9AFE55E89}        Verzweigung
# 6       {ACF238B8-5177-4239-ACD1-B402F60F5920}        Verzweigung
# 7       {1D10A30D-3B35-43AA-9F9D-6DD102D16B58}        Verzweigung
# 8       {8E730905-A989-4D50-B921-2B8E4BDD5E5F}           Ausfahrt
# 9       {F36B1E8E-978A-4F18-9060-41B7F8BF2169}           Ausfahrt
# 10      {BC682DAC-3A90-4558-A342-1BFBF028D314}           Ausfahrt
# 11      {A387414A-8051-469F-AC3F-A2D9A6C93F0D}           Ausfahrt
# 12      {1803E497-4DE1-4F95-B2F6-44EEE74C56F7}           Ausfahrt
# ...

# %%
gdf.shape
# Out:
# (308200, 12)

# %%
gdf.dtypes
# Out:
# UUID            object
# OBJEKTART       object
# OBJEKTKLAS      object
# HOEHE          float64
# GEBAEUDENU      object
# NAME_UUID       object
# NAME            object
# STATUS          object
# SPRACHCODE      object
# NAMEN_TYP       object
# NAMENGRUPP      object
# geometry      geometry
# dtype: object

# %% [markdown]
# Daten in String umwandeln ?????????????
# #df.to_string(buf=None, columns=None, col_space=None, header=True, index=True, na_rep='NaN', formatters=None, float_format=None, sparsify=None, index_names=True, justify=None, line_width=None, max_rows=None, max_cols=None, show_dimensions=False)

# %%
#gdf['NAME'].unique()

# %%
gdf['OBJEKTART'].unique()
# Out:
# array(['Ausfahrt', 'Verzweigung', 'Ein- und Ausfahrt', 'Zollamt 24h 24h',
#        'Zollamt 24h eingeschraenkt', 'Zollamt eingeschraenkt',
#        'Verladestation', 'Haltestelle Schiff', 'Haltestelle Bahn',
#        'Uebrige Bahnen', 'Haltestelle Bus', 'Flurname swisstopo',
#        'Lokalname swisstopo', 'Pass', 'Gipfel', 'Hauptgipfel',
#        'Alpiner Gipfel', 'Huegel', 'Haupthuegel', 'Felskopf',
#        'Strassenpass', 'Quelle', 'Grotte, Hoehle', 'Wasserfall',
#        'Denkmal', 'Brunnen', 'Bildstock', 'Aussichtspunkt',
#        'Landesgrenzstein', 'Erratischer Block', 'Felsblock', 'Gebaeude',
#        'Offenes Gebaeude', 'Sakrales Gebaeude', 'Kapelle', 'Turm'],
#       dtype=object)

# %%
gdf['GEBAEUDENU'].unique()
# Out:
# array(['k_W', 'Gasthof abgelegen', 'Schiessstand', 'Stadion',
#        'Schutzhuette', 'Stationsgebaeude', 'Observatorium',
#        'Aussichtsturm', 'Leuchtturm', 'Sporthalle', 'Wasserturm'],
#       dtype=object)

# %%
gdf[gdf['NAME'].str.contains("Albis")]
# Out:
#                                           UUID           OBJEKTART  \
# 674     {A8E971B0-784C-4495-A94A-BAC6C594DFB5}            Ausfahrt
# 675     {C29D546F-1E5B-40E0-BBB9-2ADB0E1150CF}            Ausfahrt
# 4234    {87A5BEB9-B7D7-434E-B6BC-6037AC85E919}    Haltestelle Bahn
# 4442    {164436C3-C255-4144-A00A-4C8FD6CCC6A4}    Haltestelle Bahn
# 4667    {AA914C98-F559-42F6-BFE2-699B0B61A479}    Haltestelle Bahn
# 4681    {06EE34DD-E8B5-465F-87E7-E8B75849B8DE}    Haltestelle Bahn
# 4682    {BC9881B4-5405-4262-B4CE-43905A6E7338}    Haltestelle Bahn
# 4683    {AA1E1F86-95A6-4ABD-8EFE-74564AD7697B}    Haltestelle Bahn
# 4684    {0D3987AB-1833-4CFE-943C-A85F37445E50}    Haltestelle Bahn
# 5893    {6FCBC968-53CC-4630-980D-04B26ABA05A9}     Haltestelle Bus
# 5958    {E2D71FE4-CBFF-4CF3-812B-4C9F1DC247F8}     Haltestelle Bus
# 8085    {B1A776A2-D603-48DA-A208-7326144DF22B}     Haltestelle Bus
# 8086    {55852872-5D3E-4EF0-BA5A-315AA722196C}     Haltestelle Bus
# ...

# %%
gdf[gdf['NAME'].str.contains("St. ")]
# Out:
#                                           UUID           OBJEKTART  \
# 49      {13467D86-8FE6-4CFD-8B05-52810AAAE742}            Ausfahrt
# 50      {47C3B0F1-2985-47C7-8DF1-E3D5AFE7FED0}            Ausfahrt
# 51      {A36CC2E1-B5D3-4634-8A45-CC268C26437E}            Ausfahrt
# 52      {A39D2F5A-270D-4EF0-AFAE-1C35E87B22DD}            Ausfahrt
# 62      {63016EA7-A2BB-4166-AF20-491C364F039B}            Ausfahrt
# 63      {847C0907-30D8-4315-8738-A1E6953CB129}            Ausfahrt
# 69      {A9DF7DD6-9ADF-4B5A-B6CC-0D824E29F4BC}            Ausfahrt
# 70      {71591F62-4FC7-43E5-9C87-5C4FFDFE65D8}            Ausfahrt
# 89      {7C21E05B-0CE3-4300-8AED-C2EDEC91D555}            Ausfahrt
# 90      {BA18022D-6BF7-4CB3-9C1A-216CEA4D5760}            Ausfahrt
# 231     {42AD7A9A-0AEE-4D8B-8D28-FED0A33426F1}            Ausfahrt
# 260     {3715C9A5-B091-4A2B-80DF-03E6B0ADB23A}            Ausfahrt
# 264     {724FE4D7-928D-43FA-AC3E-E7728DE30D23}            Ausfahrt
# ...

# %%
len(gdf[gdf['NAME'].str.contains("Anna")])
# Out:
# 44

# %%
gdf[gdf['OBJEKTART'] == 'Huegel']
# Out:
#                                           UUID OBJEKTART    OBJEKTKLAS  \
# 281919  {0445F624-C20E-45FF-95D7-2A4D0E20B00A}    Huegel  TLM_NAME_PKT
# 282098  {3E95B505-B2D9-4E4C-A007-527AC0878D43}    Huegel  TLM_NAME_PKT
# 282108  {D6B869BB-676B-4954-8A24-DF4258A38600}    Huegel  TLM_NAME_PKT
# 282109  {DFA8B81B-5DB3-4BD0-9456-7DE49409D0CA}    Huegel  TLM_NAME_PKT
# 282110  {F438359F-DE3D-487C-B16D-3BED8BAF3D33}    Huegel  TLM_NAME_PKT
# 282111  {E14D79E6-4791-4DF8-B2A1-D0D22F8EB5ED}    Huegel  TLM_NAME_PKT
# 282112  {2F2BD865-05CC-46B1-8A24-C0A6B2CEA418}    Huegel  TLM_NAME_PKT
# 282748  {B7FEE82D-2339-4057-8891-2D1511A40E6D}    Huegel  TLM_NAME_PKT
# 282750  {8883D328-A9BF-4ABE-83B8-60DAD9A4C7AC}    Huegel  TLM_NAME_PKT
# 282752  {84246220-DE0E-4A1A-8F59-DA3090C7E10B}    Huegel  TLM_NAME_PKT
# 282755  {06CEE7B3-6CAC-42B6-8E81-A8D6E4B99B4B}    Huegel  TLM_NAME_PKT
# 282757  {A4B117CD-86D3-41E9-B9F0-E20C41B9E682}    Huegel  TLM_NAME_PKT
# ...

# %%
len(gdf[gdf['OBJEKTART'] == 'Huegel'])
# Out:
# 2141

# %%
gdf[gdf['NAME'].str.contains("Triemli")]
# Out:
#                                          UUID         OBJEKTART  \
# 4244   {AE619DD3-6B6E-4FE4-801F-E163C52FCE26}  Haltestelle Bahn
# 4587   {EA48BEE8-4E36-4E82-9030-8BA142C1675C}  Haltestelle Bahn
# 15442  {B6220091-7870-4ED2-90F6-4D165FC07B65}   Haltestelle Bus
#
#             OBJEKTKLAS     HOEHE GEBAEUDENU  \
# 4244   TLM_HALTESTELLE -999998.0        k_W
# 4587   TLM_HALTESTELLE -999998.0        k_W
# 15442  TLM_HALTESTELLE -999998.0        k_W
#
#                                     NAME_UUID                   NAME  \
# 4244   {654CEFCC-CCDA-48CA-9C8B-BF437410C034}         Zürich Triemli
# 4587   {7D6A8817-E3F1-4B64-B8D9-BEF84B21F31E}        Zürich, Triemli
# 15442  {8A8CA15C-8473-43D9-A56E-6A8EEE2FE487}  Zürich, Triemlispital
#
#           STATUS                       SPRACHCODE       NAMEN_TYP NAMENGRUPP  \
# 4244   offiziell  Hochdeutsch inkl. Lokalsprachen  Einfacher Name       None
# 4587   offiziell  Hochdeutsch inkl. Lokalsprachen  Einfacher Name       None
# ...
